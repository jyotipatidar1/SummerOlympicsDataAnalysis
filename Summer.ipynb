# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
# url = 'https://raw.githubusercontent.com/KPRAPHULL/Summer-Olympics/main/Summer.csv'
from google.colab import drive

drive.mount('/content/drive')

# df = pd.read_csv(url)
# df.head(100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# --> 619         parts = [self.recv(flags, copy=copy, track=track)]
#     620         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-9c3323db6ced> in <module>()
#       3 from google.colab import drive
#       4
# ----> 5 drive.mount('/content/drive')
#       6
#       7 # df = pd.read_csv(url)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     106       force_remount=force_remount,
#     107       timeout_ms=timeout_ms,
# --> 108       use_metadata_server=use_metadata_server)
#     109
#     110
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     285       with _output.use_tags('dfs-auth-dance'):
#     286         with open(fifo, 'w') as fifo_file:
# --> 287           fifo_file.write(get_code(auth_prompt) + '\n')
#     288       wrote_to_fifo = True
#     289     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
url = '/content/Summer.csv'
df = pd.read_csv(url)
df.head(100)
# Out:
#     Year    City       Sport  ... Gender                       Event   Medal
# 0   1896  Athens    Aquatics  ...    Men              100M Freestyle    Gold
# 1   1896  Athens    Aquatics  ...    Men              100M Freestyle  Silver
# 2   1896  Athens    Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3   1896  Athens    Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4   1896  Athens    Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ..   ...     ...         ...  ...    ...                         ...     ...
# 95  1896  Athens  Gymnastics  ...    Men         Team, Parallel Bars  Bronze
# 96  1896  Athens  Gymnastics  ...    Men         Team, Parallel Bars  Bronze
# 97  1896  Athens  Gymnastics  ...    Men         Team, Parallel Bars  Bronze
# 98  1896  Athens  Gymnastics  ...    Men         Team, Parallel Bars  Bronze
# 99  1896  Athens  Gymnastics  ...    Men         Team, Parallel Bars    Gold
#
# [100 rows x 9 columns]

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)
